# %% [markdown]
# <h1>Consolidado de datos</h1>
#
#
# | <b>filename</b> | datos_audio_init.ipynb |
# | --- | --- |
# | Descripción | Notebook creado para organizar la información de los archivos de audio que se encuentran en carpetas con el id de cada paciente. Se busca organizar en una sola tabla la información de los pacientes que se encuentran en el archivo imus y marcha (1).xls con el listado de archivos de audio que tiene cada paciente. |
# | Salida | Obtener un archivo en csv "datos_audio.csv" que contengan la información del paciente y el origen de los archivos de audio. Este archivo será el insumo para el EDA. En principio sirve para conocer la cantidad de audios que tenemos por paciente, la duración de los audios y caracteristicas más generales de los archivos |

# %%
import os
import pandas as pd
import wave

# %%
#Ruta donde se encuentran los archivos de audio
ruta_archivos = '..\\data\\wavFiles'


#Ruta del excel que contiene la información de los pacientes
ruta_excel_pacientes = '..\\data\\imus y marcha (1).xls'
ruta_excel_salida = '..\\data\\informacion_pacientes.csv'

#Los audios de los pacientes están separados por carpeta
ids =  [nombre for nombre in os.listdir(ruta_archivos) if os.path.isdir(os.path.join(ruta_archivos, nombre))]

# %% [markdown]
# <h2>1. Lectura de archivos de audio</h2>
#
# Se buscan los archivos de audio ubicados en ruta_archivos, se guarda el nombre de los archivos con el nombre de la carpeta que los contiene (debe ser el id de cada paciente).
#
# Finalmente en el dataframe df_audios se guarda la información de cada uno de los archivos encontrados para cada paciente

# %%
#Se recorre cada subcarpeta para recoger la información de los audios grabados
audios_data = []

#ids contiene el listado de carpetas en wavfiles, que deben ser los id de los pacientes.
for id in ids:
    audio_data = {}
    audio_id = os.path.join(ruta_archivos, id)
    audio_data['id'] = id
    
    # Verificar que la carpeta existe
    if os.path.isdir(audio_id):
        
        #Se guarda el listado de archivos en cada subcarpeta, solo se buscan archivos con extensión wav o WAV
        archivos_audio = [
            f for f in os.listdir(audio_id)
            if os.path.isfile(os.path.join(audio_id, f)) and
            os.path.splitext(f)[1].lower() in ['.wav','.WAV']]
        
        audio_data['numero_archivos'] = len(archivos_audio)

        #Se abre cada archivo y se lee 
        for archivo in archivos_audio:

            try:
                with wave.open(os.path.join(audio_id,archivo), 'rb') as wav_file:
                    frames = wav_file.getnframes()
                    channels = wav_file.getnchannels()
                    rate = wav_file.getframerate()
                    duracion = frames / float(rate)
            except Exception as e:
                duracion = None
                print(f"Error leyendo '{archivo}': {e}")

            if 'moca_p' in archivo.lower():
                audio_data['file_MoCA_P'] = archivo
                audio_data['lenght_MoCA_P'] = duracion
                audio_data['rate_MoCA_P'] = rate
                audio_data['channels_MoCA_P'] = channels
            elif 'animales' in archivo.lower():
                audio_data['file_Animales'] = archivo
                audio_data['lenght_Animales'] = duracion
                audio_data['rate_Animales'] = rate
                audio_data['channels_Animales'] = channels
            elif 'frutas' in archivo.lower():
                audio_data['file_Frutas'] = archivo
                audio_data['lenght_Frutas'] = duracion
                audio_data['rate_Frutas'] = rate
                audio_data['channels_Frutas'] = channels
            elif '_a_' in archivo.lower():
                audio_data['file_A'] = archivo
                audio_data['lenght_A'] = duracion
                audio_data['rate_Frutas'] = rate
                audio_data['channels_Frutas'] = channels
            elif '_f_' in archivo.lower():
                audio_data['file_F'] = archivo
                audio_data['lenght_F'] = duracion
                audio_data['rate_F'] = rate
                audio_data['channels_F'] = channels
            elif '_m_' in archivo.lower():
                audio_data['file_M'] = archivo
                audio_data['lenght_M'] = duracion
                audio_data['rate_M'] = rate
                audio_data['channels_M'] = channels

        audios_data.append(audio_data)
    else:
        print(f"La carpeta '{audio_id}' no existe.")

audios_data
# Out:
# [{'id': '102907369',
#   'numero_archivos': 6,
#   'file_MoCA_P': '102907369_MoCA_P_Letter_1686929951416.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '102907369_Prueba_Fluidez_Verbal_Animales_Letter_1686930633860.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '102907369_Prueba_Fluidez_Verbal_A_Letter_1686930483405.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '102907369_Prueba_Fluidez_Verbal_Frutas_Letter_1686930704334.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '102907369_Prueba_Fluidez_Verbal_F_Letter_1686930408845.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '102907369_Prueba_Fluidez_Verbal_M_Letter_1686930552121.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '10523391',
#   'numero_archivos': 6,
#   'file_MoCA_P': '10523391_MoCA_P_Letter_1686952907610.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '10523391_Prueba_Fluidez_Verbal_Animales_Letter_1686954259979.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '10523391_Prueba_Fluidez_Verbal_A_Letter_1686954123050.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '10523391_Prueba_Fluidez_Verbal_Frutas_Letter_1686954326498.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '10523391_Prueba_Fluidez_Verbal_F_Letter_1686954052110.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '10523391_Prueba_Fluidez_Verbal_M_Letter_1686954190464.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '10526776',
#   'numero_archivos': 6,
#   'file_MoCA_P': '10526776_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '10526776_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '10526776_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '10526776_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '10526776_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '10526776_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '10529624',
#   'numero_archivos': 6,
#   'file_MoCA_P': '10529624_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '10529624_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '10529624_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '10529624_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '10529624_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.392,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '10529624_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '10529944',
#   'numero_archivos': 6,
#   'file_MoCA_P': '10529944_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '10529944_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '10529944_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '10529944_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '10529944_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '10529944_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '10530165',
#   'numero_archivos': 6,
#   'file_MoCA_P': '10530165_MoCA_P_Letter_1686934792935.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '10530165_Prueba_Fluidez_Verbal_Animales_Letter_1686935522035.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '10530165_Prueba_Fluidez_Verbal_A_Letter_1686935369408.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '10530165_Prueba_Fluidez_Verbal_Frutas_Letter_1686935591019.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '10530165_Prueba_Fluidez_Verbal_F_Letter_1686935300147.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '10530165_Prueba_Fluidez_Verbal_M_Letter_1686935445090.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '10539008',
#   'numero_archivos': 6,
#   'file_MoCA_P': '10539008_MoCA_P_Letter_1687011952859.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '10539008_Prueba_Fluidez_Verbal_Animales_Letter_1687011000319.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '10539008_Prueba_Fluidez_Verbal_A_Letter_1687010852484.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '10539008_Prueba_Fluidez_Verbal_Frutas_Letter_1687011071327.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '10539008_Prueba_Fluidez_Verbal_F_Letter_1687010780252.wav',
#   'lenght_F': 59.392,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '10539008_Prueba_Fluidez_Verbal_M_Letter_1687010931163.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '10542415',
#   'numero_archivos': 6,
#   'file_MoCA_P': '10542415_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '10542415_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '10542415_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '10542415_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '10542415_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '10542415_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '10549676',
#   'numero_archivos': 6,
#   'file_MoCA_P': '10549676_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '10549676_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '10549676_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '10549676_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '10549676_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.648,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '10549676_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '10565704',
#   'numero_archivos': 6,
#   'file_MoCA_P': '10565704_MoCA_P_Letter_1686946671217.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '10565704_Prueba_Fluidez_Verbal_Animales_Letter_1686945735187.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '10565704_Prueba_Fluidez_Verbal_A_Letter_1686945598592.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '10565704_Prueba_Fluidez_Verbal_Frutas_Letter_1686945801556.wav',
#   'lenght_Frutas': 52.992,
#   'file_F': '10565704_Prueba_Fluidez_Verbal_F_Letter_1686945527630.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '10565704_Prueba_Fluidez_Verbal_M_Letter_1686945666072.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '1113672747',
#   'numero_archivos': 6,
#   'file_MoCA_P': '1113672747_MoCA_P_Letter_1687020415191.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '1113672747_Prueba_Fluidez_Verbal_Animales_Letter_1687021176429.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '1113672747_Prueba_Fluidez_Verbal_A_Letter_1687021021303.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '1113672747_Prueba_Fluidez_Verbal_Frutas_Letter_1687021246702.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '1113672747_Prueba_Fluidez_Verbal_F_Letter_1687020934763.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '1113672747_Prueba_Fluidez_Verbal_M_Letter_1687021095953.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '12269311',
#   'numero_archivos': 5,
#   'file_Animales': '12269311_Prueba_Fluidez_Verbal_Animales_Letter_1687017971633.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '12269311_Prueba_Fluidez_Verbal_A_Letter_1687017838027.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '12269311_Prueba_Fluidez_Verbal_Frutas_Letter_1687018041409.wav',
#   'lenght_Frutas': 59.648,
#   'file_F': '12269311_Prueba_Fluidez_Verbal_F_Letter_1687017762264.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '12269311_Prueba_Fluidez_Verbal_M_Letter_1687017902864.wav',
#   'lenght_M': 59.648,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '13012517',
#   'numero_archivos': 6,
#   'file_MoCA_P': '13012517_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '13012517_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.648,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '13012517_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.648,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '13012517_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.648,
#   'file_F': '13012517_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.392,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '13012517_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.648,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '1496380',
#   'numero_archivos': 3,
#   'file_Animales': '1496380_Prueba_Fluidez_Verbal_Animales_Letter_1687016440139.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_Frutas': '1496380_Prueba_Fluidez_Verbal_Frutas_Letter_1687016505079.wav',
#   'lenght_Frutas': 59.648,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_M': '1496380_Prueba_Fluidez_Verbal_M_Letter_1687016406795.wav',
#   'lenght_M': 26.24,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '14991897',
#   'numero_archivos': 6,
#   'file_MoCA_P': '14991897_MoCA_P_Letter_1687011608798.wav',
#   'lenght_MoCA_P': 59.392,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '14991897_Prueba_Fluidez_Verbal_Animales_Letter_1687012110334.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '14991897_Prueba_Fluidez_Verbal_A_Letter_1687011965994.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '14991897_Prueba_Fluidez_Verbal_Frutas_Letter_1687012175698.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '14991897_Prueba_Fluidez_Verbal_F_Letter_1687011895814.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '14991897_Prueba_Fluidez_Verbal_M_Letter_1687012038235.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '14998308',
#   'numero_archivos': 6,
#   'file_MoCA_P': '14998308_MoCA_P_Letter_1686928936279.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '14998308_Prueba_Fluidez_Verbal_Animales_Letter_1686927267749.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '14998308_Prueba_Fluidez_Verbal_A_Letter_1686927094402.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '14998308_Prueba_Fluidez_Verbal_Frutas_Letter_1686927343413.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '14998308_Prueba_Fluidez_Verbal_F_Letter_1686927010352.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '14998308_Prueba_Fluidez_Verbal_M_Letter_1686927170049.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '1505001',
#   'numero_archivos': 6,
#   'file_MoCA_P': '1505001_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '1505001_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '1505001_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '1505001_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '1505001_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '1505001_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '17095003',
#   'numero_archivos': 6,
#   'file_MoCA_P': '17095003_MoCA_P_Letter_1686932118531.wav',
#   'lenght_MoCA_P': 60.288,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '17095003_Prueba_Fluidez_Verbal_Animales_Letter_1686932868544.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '17095003_Prueba_Fluidez_Verbal_A_Letter_1686932714961.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '17095003_Prueba_Fluidez_Verbal_Frutas_Letter_1686932936853.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '17095003_Prueba_Fluidez_Verbal_F_Letter_1686932646724.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '17095003_Prueba_Fluidez_Verbal_M_Letter_1686932788205.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '25268997',
#   'numero_archivos': 5,
#   'file_Animales': '25268997_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '25268997_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '25268997_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '25268997_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '25268997_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '25270259',
#   'numero_archivos': 3,
#   'file_A': '25270259_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_F': '25270259_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '25270259_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '25270459',
#   'numero_archivos': 6,
#   'file_MoCA_P': '25270459_MoCA_P_Letter_1686927432751.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '25270459_Prueba_Fluidez_Verbal_Animales_Letter_1686928377870.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '25270459_Prueba_Fluidez_Verbal_A_Letter_1686928238352.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '25270459_Prueba_Fluidez_Verbal_Frutas_Letter_1686928458260.wav',
#   'lenght_Frutas': 54.912,
#   'file_F': '25270459_Prueba_Fluidez_Verbal_F_Letter_1686928170262.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '25270459_Prueba_Fluidez_Verbal_M_Letter_1686928306479.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '25395208',
#   'numero_archivos': 6,
#   'file_MoCA_P': '25395208_MoCA_P_Letter_1686950834607.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '25395208_Prueba_Fluidez_Verbal_Animales_Letter_1686951673706.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '25395208_Prueba_Fluidez_Verbal_A_Letter_1686951538519.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '25395208_Prueba_Fluidez_Verbal_Frutas_Letter_1686951739875.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '25395208_Prueba_Fluidez_Verbal_F_Letter_1686951471640.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '25395208_Prueba_Fluidez_Verbal_M_Letter_1686951604955.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '25404370',
#   'numero_archivos': 6,
#   'file_MoCA_P': '25404370_MoCA_P_Letter_1687025078683.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '25404370_Prueba_Fluidez_Verbal_Animales_Letter_1687023974059.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '25404370_Prueba_Fluidez_Verbal_A_Letter_1687023828689.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '25404370_Prueba_Fluidez_Verbal_Frutas_Letter_1687024045372.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '25404370_Prueba_Fluidez_Verbal_F_Letter_1687023750272.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '25404370_Prueba_Fluidez_Verbal_M_Letter_1687023898081.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '25706093',
#   'numero_archivos': 6,
#   'file_MoCA_P': '25706093_MoCA_P_Letter_1687014280572.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '25706093_Prueba_Fluidez_Verbal_Animales_Letter_1687012725578.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '25706093_Prueba_Fluidez_Verbal_A_Letter_1687012565170.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '25706093_Prueba_Fluidez_Verbal_Frutas_Letter_1687012791418.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '25706093_Prueba_Fluidez_Verbal_F_Letter_1687012496240.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '25706093_Prueba_Fluidez_Verbal_M_Letter_1687012645011.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '25714829',
#   'numero_archivos': 6,
#   'file_MoCA_P': '25714829_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '25714829_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '25714829_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '25714829_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '25714829_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '25714829_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '34500978',
#   'numero_archivos': 1,
#   'file_MoCA_P': '34500978_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1},
#  {'id': '34525358',
#   'numero_archivos': 5,
#   'file_Animales': '34525358_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '34525358_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '34525358_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '34525358_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '34525358_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '34531841',
#   'numero_archivos': 6,
#   'file_MoCA_P': '34531841_MoCA_P_Letter_1686947742837.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '34531841_Prueba_Fluidez_Verbal_Animales_Letter_1686949599269.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '34531841_Prueba_Fluidez_Verbal_A_Letter_1686949418849.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '34531841_Prueba_Fluidez_Verbal_Frutas_Letter_1686949683829.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '34531841_Prueba_Fluidez_Verbal_F_Letter_1686949340488.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '34531841_Prueba_Fluidez_Verbal_M_Letter_1686949507750.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '34534829',
#   'numero_archivos': 6,
#   'file_MoCA_P': '34534829_MoCA_P_Letter_1686955756795.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '34534829_Prueba_Fluidez_Verbal_Animales_Letter_1686954741236.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '34534829_Prueba_Fluidez_Verbal_A_Letter_1686954594654.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '34534829_Prueba_Fluidez_Verbal_Frutas_Letter_1686954810449.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '34534829_Prueba_Fluidez_Verbal_F_Letter_1686954518085.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '34534829_Prueba_Fluidez_Verbal_M_Letter_1686954671734.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '34539277',
#   'numero_archivos': 6,
#   'file_MoCA_P': '34539277_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '34539277_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '34539277_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '34539277_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '34539277_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '34539277_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '34540520',
#   'numero_archivos': 6,
#   'file_MoCA_P': '34540520_MoCA_P_Letter_1686922642368.wav',
#   'lenght_MoCA_P': 59.392,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '34540520_Prueba_Fluidez_Verbal_Animales_Letter_1686923361579.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '34540520_Prueba_Fluidez_Verbal_A_Letter_1686923219783.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '34540520_Prueba_Fluidez_Verbal_Frutas_Letter_1686923433012.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '34540520_Prueba_Fluidez_Verbal_F_Letter_1686923145149.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '34540520_Prueba_Fluidez_Verbal_M_Letter_1686923287628.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '34548719',
#   'numero_archivos': 6,
#   'file_MoCA_P': '34548719_MoCA_P_Letter_1686948857750.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '34548719_Prueba_Fluidez_Verbal_Animales_Letter_1686948073648.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '34548719_Prueba_Fluidez_Verbal_A_Letter_1686947891324.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '34548719_Prueba_Fluidez_Verbal_Frutas_Letter_1686948153372.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '34548719_Prueba_Fluidez_Verbal_F_Letter_1686947766226.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '34548719_Prueba_Fluidez_Verbal_M_Letter_1686947990907.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '34552215',
#   'numero_archivos': 6,
#   'file_MoCA_P': '34552215_MoCA_P_Letter_1687013315313.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '34552215_Prueba_Fluidez_Verbal_Animales_Letter_1687014912831.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '34552215_Prueba_Fluidez_Verbal_A_Letter_1687014759561.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '34552215_Prueba_Fluidez_Verbal_Frutas_Letter_1687014982343.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '34552215_Prueba_Fluidez_Verbal_F_Letter_1687014690786.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '34552215_Prueba_Fluidez_Verbal_M_Letter_1687014833755.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '38980722',
#   'numero_archivos': 6,
#   'file_MoCA_P': '38980722_MoCA_P_Letter_1686953449049.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '38980722_Prueba_Fluidez_Verbal_Animales_Letter_1686951814546.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '38980722_Prueba_Fluidez_Verbal_A_Letter_1686951665405.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '38980722_Prueba_Fluidez_Verbal_Frutas_Letter_1686951900795.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '38980722_Prueba_Fluidez_Verbal_F_Letter_1686951578130.wav',
#   'lenght_F': 59.392,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '38980722_Prueba_Fluidez_Verbal_M_Letter_1686951741234.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '4663131',
#   'numero_archivos': 6,
#   'file_MoCA_P': '4663131_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '4663131_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '4663131_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '4663131_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '4663131_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '4663131_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '4778582',
#   'numero_archivos': 6,
#   'file_MoCA_P': '4778582_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '4778582_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '4778582_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '4778582_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '4778582_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '4778582_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '76305878',
#   'numero_archivos': 6,
#   'file_MoCA_P': '76305878_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '76305878_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '76305878_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '76305878_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '76305878_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '76305878_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '76307307',
#   'numero_archivos': 1,
#   'file_MoCA_P': '76307307_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1},
#  {'id': '76310238',
#   'numero_archivos': 6,
#   'file_MoCA_P': '76310238_MoCA_P_Letter.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '76310238_Prueba_Fluidez_Verbal_Animales_Letter.wav',
#   'lenght_Animales': 60.16,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '76310238_Prueba_Fluidez_Verbal_A_Letter.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '76310238_Prueba_Fluidez_Verbal_Frutas_Letter.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '76310238_Prueba_Fluidez_Verbal_F_Letter.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '76310238_Prueba_Fluidez_Verbal_M_Letter.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1},
#  {'id': '76312965',
#   'numero_archivos': 6,
#   'file_MoCA_P': '76312965_MoCA_P_Letter_1686945690670.wav',
#   'lenght_MoCA_P': 59.52,
#   'rate_MoCA_P': 16000,
#   'channels_MoCA_P': 1,
#   'file_Animales': '76312965_Prueba_Fluidez_Verbal_Animales_Letter_1686946920473.wav',
#   'lenght_Animales': 59.52,
#   'rate_Animales': 16000,
#   'channels_Animales': 1,
#   'file_A': '76312965_Prueba_Fluidez_Verbal_A_Letter_1686946733988.wav',
#   'lenght_A': 59.52,
#   'rate_Frutas': 16000,
#   'channels_Frutas': 1,
#   'file_Frutas': '76312965_Prueba_Fluidez_Verbal_Frutas_Letter_1686946993371.wav',
#   'lenght_Frutas': 59.52,
#   'file_F': '76312965_Prueba_Fluidez_Verbal_F_Letter_1686946664765.wav',
#   'lenght_F': 59.52,
#   'rate_F': 16000,
#   'channels_F': 1,
#   'file_M': '76312965_Prueba_Fluidez_Verbal_M_Letter_1686946835553.wav',
#   'lenght_M': 59.52,
#   'rate_M': 16000,
#   'channels_M': 1}]

# %%
#se convierte la información de los archivos de audio en dataframe para combinarlo con la información de los pacientes en el archivo "imus y marcha (1).xls"
df_audios = pd.DataFrame(audios_data)
df_audios.head()
# Out:
#           id  numero_archivos                                file_MoCA_P  \
# 0  102907369                6  102907369_MoCA_P_Letter_1686929951416.wav
# 1   10523391                6   10523391_MoCA_P_Letter_1686952907610.wav
# 2   10526776                6                 10526776_MoCA_P_Letter.wav
# 3   10529624                6                 10529624_MoCA_P_Letter.wav
# 4   10529944                6                 10529944_MoCA_P_Letter.wav
#
#    lenght_MoCA_P  rate_MoCA_P  channels_MoCA_P  \
# 0          59.52      16000.0              1.0
# 1          59.52      16000.0              1.0
# 2          59.52      16000.0              1.0
# 3          59.52      16000.0              1.0
# 4          59.52      16000.0              1.0
#
#                                        file_Animales  lenght_Animales  \
# 0  102907369_Prueba_Fluidez_Verbal_Animales_Lette...            59.52
# 1  10523391_Prueba_Fluidez_Verbal_Animales_Letter...            59.52
# 2  10526776_Prueba_Fluidez_Verbal_Animales_Letter...            59.52
# 3  10529624_Prueba_Fluidez_Verbal_Animales_Letter...            59.52
# 4  10529944_Prueba_Fluidez_Verbal_Animales_Letter...            59.52
#
#    rate_Animales  channels_Animales  ...  \
# 0        16000.0                1.0  ...
# 1        16000.0                1.0  ...
# 2        16000.0                1.0  ...
# 3        16000.0                1.0  ...
# 4        16000.0                1.0  ...
#
#                                          file_Frutas  lenght_Frutas  \
# 0  102907369_Prueba_Fluidez_Verbal_Frutas_Letter_...          59.52
# 1  10523391_Prueba_Fluidez_Verbal_Frutas_Letter_1...          59.52
# 2   10526776_Prueba_Fluidez_Verbal_Frutas_Letter.wav          59.52
# 3   10529624_Prueba_Fluidez_Verbal_Frutas_Letter.wav          59.52
# 4   10529944_Prueba_Fluidez_Verbal_Frutas_Letter.wav          59.52
#
#                                               file_F  lenght_F   rate_F  \
# 0  102907369_Prueba_Fluidez_Verbal_F_Letter_16869...    59.520  16000.0
# 1  10523391_Prueba_Fluidez_Verbal_F_Letter_168695...    59.520  16000.0
# 2        10526776_Prueba_Fluidez_Verbal_F_Letter.wav    59.520  16000.0
# 3        10529624_Prueba_Fluidez_Verbal_F_Letter.wav    59.392  16000.0
# 4        10529944_Prueba_Fluidez_Verbal_F_Letter.wav    59.520  16000.0
#
#    channels_F                                             file_M  lenght_M  \
# 0         1.0  102907369_Prueba_Fluidez_Verbal_M_Letter_16869...     59.52
# 1         1.0  10523391_Prueba_Fluidez_Verbal_M_Letter_168695...     59.52
# 2         1.0        10526776_Prueba_Fluidez_Verbal_M_Letter.wav     59.52
# 3         1.0        10529624_Prueba_Fluidez_Verbal_M_Letter.wav     59.52
# 4         1.0        10529944_Prueba_Fluidez_Verbal_M_Letter.wav     59.52
#
#     rate_M  channels_M
# 0  16000.0         1.0
# 1  16000.0         1.0
# 2  16000.0         1.0
# 3  16000.0         1.0
# 4  16000.0         1.0
#
# [5 rows x 24 columns]

# %% [markdown]
# <h2>2. Lectura de archivo excel con la información del paciente</h2>
#
# Se lee el archivo en el dataframe df_excel, se crea la columna id y se formatea para se usada como llave para unirlo con el dataframe de los archivos de audio

# %%
#Carga el excel en un dataframe
df_excel = pd.read_excel(ruta_excel_pacientes)
df_excel.head()
# Out:
#      Record ID      Cédula                Fecha  Marcha  Edad  \
# 0  GEO_REF0001   4663131.0  2023-07-26 00:00:00     1.0  75.0
# 1  GEO_REF0002  25714829.0  2023-07-26 00:00:00     3.0  68.0
# 2  GEO_REF0003  10542415.0  2023-07-26 00:00:00     1.0  60.0
# 3  GEO_REF0004  10526776.0  2023-07-26 00:00:00     2.0  70.0
# 4  GEO_REF0005  25268997.0  2023-07-26 00:00:00     4.0  79.0
#
#    Puntaje total MDS UPDRS  H&J  Lateralidad  C/C
# 0                     40.0  3.0          2.0    1
# 1                     60.0  3.0          1.0    1
# 2                     19.0  2.0          1.0    1
# 3                     34.0  2.0          1.0    1
# 4                     55.0  4.0          2.0    1

# %%
#Se ajustan los id de cada Dataframe
df_excel['id'] = df_excel['Cédula'].astype(str).str.replace('.0', '', regex=False)
df_audios['id'] = df_audios['id'].astype(str)

# %% [markdown]
# <h2>3. Combinar los dataframes</h3>
#
# Se combina la información del excel con la información de los archivos de audio recolectada

# %%
#Combina los dataframes con el id como llave
df_final = pd.merge(df_audios,df_excel,on='id',how='left')

# %%
#Se revisa si hay archivos de audio sin información
print(df_final.shape)
print(df_excel.shape)
print(df_audios.shape)
# Out:
# (40, 33)
# (160, 10)
# (40, 24)

# %% [markdown]
# <h2>4. Guarda el dataframe en un csv</h2>

# %%
df_final.to_csv(ruta_excel_salida,encoding='utf-8',index=False)
