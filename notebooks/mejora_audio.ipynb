# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r /content/drive/MyDrive/speech-enhancement-sgmse/requirements.txt

# %%
# !python /content/drive/MyDrive/speech-enhancement-sgmse/enhancement.py --test_dir /content/drive/MyDrive/speech-enhancement-sgmse/audios/ --enhanced_dir /content/drive/MyDrive/speech-enhancement-sgmse/audios_mejorados/ --ckpt /content/drive/MyDrive/speech-enhancement-sgmse/train_vb_29nqe0uh_epoch=115.ckpt
# Out:
# Set TORCH_CUDA_ARCH_LIST to: 8.0
# Lightning automatically upgraded your loaded checkpoint from v1.5.10 to v2.5.1.post0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint drive/MyDrive/speech-enhancement-sgmse/train_vb_29nqe0uh_epoch=115.ckpt`
# 100% 166/166 [1:35:11<00:00, 34.41s/it]
